# %%
import os
os.chdir('../')  # 更改notebook的工作路径到上一级目录

# %%
import cv2
import numpy as np

import torch
import torch.nn.functional as F
from torchvision import transforms

from model.fcos import FCOSDetector
from model.config import DefaultConfig

# %% [markdown]
# ## 模型转换之Pytorch --> ONNX

# %%
# 首先建立一个新的FCOSDetectorDeploy，目的是在forward里增加一个deploy模式
class FCOSDetectorDeploy(FCOSDetector):
    def __init__(self,mode="training",config=None):
        super().__init__(mode=mode, config=config)

    def forward(self,inputs):
        '''
        inputs
        [training] list  batch_imgs,batch_boxes,batch_classes
        [inference] img
        '''

        if self.mode=="training":
            batch_imgs,batch_boxes,batch_classes=inputs
            out=self.fcos_body(batch_imgs)
            targets=self.target_layer([out,batch_boxes,batch_classes])
            losses=self.loss_layer([out,targets])
            return losses
        elif self.mode=="inference":
            # raise NotImplementedError("no implement inference model")
            '''
            for inference mode, img should preprocessed before feeding in net
            '''
            batch_imgs=inputs
            out=self.fcos_body(batch_imgs)
            scores,classes,boxes=self.detection_head(out)
            boxes=self.clip_boxes(batch_imgs,boxes)
            return scores,classes,boxes

        # 相对于原来的FCOSDetector，增加了deploy模式，相比之前的inference，
        # deploy模式的输出是三个concat后的tensor。同样，为了将计算尽可能保留
        # 在模型内，这里的forward提前调用的sigmoid()函数
        elif self.mode=="deploy":
            
            out = self.fcos_body(inputs)
            # Step 1. Concat Cls Output, cls_out shape [1,20,#anchor points]
            cls_out = F.sigmoid(torch.cat([out[0][i].view(1,20,-1) for i in range(len(out[0]))], -1))
            # Step 2. Concat Cnt Output, cnt_out shape [1,1,#anchor points]
            cnt_out = F.sigmoid(torch.cat([out[1][i].view(1,1,-1) for i in range(len(out[1]))], -1))
            # Step 3. Concat Reg Output, reg_out shape [1,4,#anchor points]
            reg_out = torch.cat([out[2][i].view(1,4,-1) for i in range(len(out[2]))], -1)
            
            return cls_out,cnt_out,reg_out

# %%
# 以deploy模式建立一个FCOS检测器
model = FCOSDetectorDeploy(mode="deploy", config=DefaultConfig)
model = torch.nn.DataParallel(model)

# 加载训练好的模型，并开启eval()模式
model.load_state_dict(torch.load("./training_dir_fp16_nogn/model_24.pth",map_location=torch.device('cpu')))
model = model.eval()

# 建立dummy_input，固定推理阶段输入图片的长和宽
inference_h = 320
inference_w = 320
dummy_input = torch.randn(1, 3, inference_h, inference_w)

# 确定模型的输入名称和输出节点名称
input_names = ['img']
output_names = ['cls', 'cnt', 'reg']

# 转换模型
name_converted = 'fcos.onnx'
torch.onnx.export(model.module, dummy_input, name_converted, verbose=True, input_names=input_names, output_names=output_names)
# Out:
# INFO: using darnet19 backbone
# /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1386: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# graph(%img : Float(1, 3, 320, 320),
#       %fcos_body.backbone.block1.0.weight : Float(32, 3, 3, 3),
#       %fcos_body.backbone.block1.1.weight : Float(32),
#       %fcos_body.backbone.block1.1.bias : Float(32),
#       %fcos_body.backbone.block1.1.running_mean : Float(32),
#       %fcos_body.backbone.block1.1.running_var : Float(32),
#       %fcos_body.backbone.block1.1.num_batches_tracked : Long(),
#       %fcos_body.backbone.block1.4.weight : Float(64, 32, 3, 3),
#       %fcos_body.backbone.block1.5.weight : Float(64),
#       %fcos_body.backbone.block1.5.bias : Float(64),
#       %fcos_body.backbone.block1.5.running_mean : Float(64),
#       %fcos_body.backbone.block1.5.running_var : Float(64),
#       %fcos_body.backbone.block1.5.num_batches_tracked : Long(),
#       %fcos_body.backbone.block1.8.weight : Float(128, 64, 3, 3),
#       %fcos_body.backbone.block1.9.weight : Float(128),
#       %fcos_body.backbone.block1.9.bias : Float(128),
#       %fcos_body.backbone.block1.9.running_mean : Float(128),
#       %fcos_body.backbone.block1.9.running_var : Float(128),
#       %fcos_body.backbone.block1.9.num_batches_tracked : Long(),
#       %fcos_body.backbone.block1.11.weight : Float(64, 128, 1, 1),
#       %fcos_body.backbone.block1.12.weight : Float(64),
#       %fcos_body.backbone.block1.12.bias : Float(64),
#       %fcos_body.backbone.block1.12.running_mean : Float(64),
#       %fcos_body.backbone.block1.12.running_var : Float(64),
#       %fcos_body.backbone.block1.12.num_batches_tracked : Long(),
#       %fcos_body.backbone.block1.14.weight : Float(128, 64, 3, 3),
#       %fcos_body.backbone.block1.15.weight : Float(128),
#       %fcos_body.backbone.block1.15.bias : Float(128),
#       %fcos_body.backbone.block1.15.running_mean : Float(128),
#       %fcos_body.backbone.block1.15.running_var : Float(128),
#       %fcos_body.backbone.block1.15.num_batches_tracked : Long(),
#       %fcos_body.backbone.block1.18.weight : Float(256, 128, 3, 3),
#       %fcos_body.backbone.block1.19.weight : Float(256),
#       %fcos_body.backbone.block1.19.bias : Float(256),
#       %fcos_body.backbone.block1.19.running_mean : Float(256),
#       %fcos_body.backbone.block1.19.running_var : Float(256),
#       %fcos_body.backbone.block1.19.num_batches_tracked : Long(),
#       %fcos_body.backbone.block1.21.weight : Float(128, 256, 1, 1),
#       %fcos_body.backbone.block1.22.weight : Float(128),
#       %fcos_body.backbone.block1.22.bias : Float(128),
#       %fcos_body.backbone.block1.22.running_mean : Float(128),
#       %fcos_body.backbone.block1.22.running_var : Float(128),
#       %fcos_body.backbone.block1.22.num_batches_tracked : Long(),
#       %fcos_body.backbone.block1.24.weight : Float(256, 128, 3, 3),
#       %fcos_body.backbone.block1.25.weight : Float(256),
#       %fcos_body.backbone.block1.25.bias : Float(256),
#       %fcos_body.backbone.block1.25.running_mean : Float(256),
#       %fcos_body.backbone.block1.25.running_var : Float(256),
#       %fcos_body.backbone.block1.25.num_batches_tracked : Long(),
#       %fcos_body.backbone.block2.1.weight : Float(512, 256, 3, 3),
#       %fcos_body.backbone.block2.2.weight : Float(512),
#       %fcos_body.backbone.block2.2.bias : Float(512),
#       %fcos_body.backbone.block2.2.running_mean : Float(512),
#       %fcos_body.backbone.block2.2.running_var : Float(512),
#       %fcos_body.backbone.block2.2.num_batches_tracked : Long(),
#       %fcos_body.backbone.block2.4.weight : Float(256, 512, 1, 1),
#       %fcos_body.backbone.block2.5.weight : Float(256),
#       %fcos_body.backbone.block2.5.bias : Float(256),
#       %fcos_body.backbone.block2.5.running_mean : Float(256),
#       %fcos_body.backbone.block2.5.running_var : Float(256),
#       %fcos_body.backbone.block2.5.num_batches_tracked : Long(),
#       %fcos_body.backbone.block2.7.weight : Float(512, 256, 3, 3),
#       %fcos_body.backbone.block2.8.weight : Float(512),
#       %fcos_body.backbone.block2.8.bias : Float(512),
#       %fcos_body.backbone.block2.8.running_mean : Float(512),
#       %fcos_body.backbone.block2.8.running_var : Float(512),
#       %fcos_body.backbone.block2.8.num_batches_tracked : Long(),
#       %fcos_body.backbone.block2.10.weight : Float(256, 512, 1, 1),
#       %fcos_body.backbone.block2.11.weight : Float(256),
#       %fcos_body.backbone.block2.11.bias : Float(256),
#       %fcos_body.backbone.block2.11.running_mean : Float(256),
#       %fcos_body.backbone.block2.11.running_var : Float(256),
#       %fcos_body.backbone.block2.11.num_batches_tracked : Long(),
#       %fcos_body.backbone.block2.13.weight : Float(512, 256, 3, 3),
#       %fcos_body.backbone.block2.14.weight : Float(512),
#       %fcos_body.backbone.block2.14.bias : Float(512),
#       %fcos_body.backbone.block2.14.running_mean : Float(512),
#       %fcos_body.backbone.block2.14.running_var : Float(512),
#       %fcos_body.backbone.block2.14.num_batches_tracked : Long(),
#       %fcos_body.backbone.block3.1.weight : Float(1024, 512, 3, 3),
#       %fcos_body.backbone.block3.2.weight : Float(1024),
#       %fcos_body.backbone.block3.2.bias : Float(1024),
#       %fcos_body.backbone.block3.2.running_mean : Float(1024),
#       %fcos_body.backbone.block3.2.running_var : Float(1024),
#       %fcos_body.backbone.block3.2.num_batches_tracked : Long(),
#       %fcos_body.backbone.block3.4.weight : Float(512, 1024, 1, 1),
#       %fcos_body.backbone.block3.5.weight : Float(512),
#       %fcos_body.backbone.block3.5.bias : Float(512),
#       %fcos_body.backbone.block3.5.running_mean : Float(512),
#       %fcos_body.backbone.block3.5.running_var : Float(512),
#       %fcos_body.backbone.block3.5.num_batches_tracked : Long(),
#       %fcos_body.backbone.block3.7.weight : Float(1024, 512, 3, 3),
#       %fcos_body.backbone.block3.8.weight : Float(1024),
#       %fcos_body.backbone.block3.8.bias : Float(1024),
#       %fcos_body.backbone.block3.8.running_mean : Float(1024),
#       %fcos_body.backbone.block3.8.running_var : Float(1024),
#       %fcos_body.backbone.block3.8.num_batches_tracked : Long(),
#       %fcos_body.backbone.block3.10.weight : Float(512, 1024, 1, 1),
#       %fcos_body.backbone.block3.11.weight : Float(512),
#       %fcos_body.backbone.block3.11.bias : Float(512),
#       %fcos_body.backbone.block3.11.running_mean : Float(512),
#       %fcos_body.backbone.block3.11.running_var : Float(512),
#       %fcos_body.backbone.block3.11.num_batches_tracked : Long(),
#       %fcos_body.backbone.block3.13.weight : Float(1024, 512, 3, 3),
#       %fcos_body.backbone.block3.14.weight : Float(1024),
#       %fcos_body.backbone.block3.14.bias : Float(1024),
#       %fcos_body.backbone.block3.14.running_mean : Float(1024),
#       %fcos_body.backbone.block3.14.running_var : Float(1024),
#       %fcos_body.backbone.block3.14.num_batches_tracked : Long(),
#       %fcos_body.fpn.prj_5.weight : Float(256, 1024, 1, 1),
#       %fcos_body.fpn.prj_5.bias : Float(256),
#       %fcos_body.fpn.prj_4.weight : Float(256, 512, 1, 1),
#       %fcos_body.fpn.prj_4.bias : Float(256),
#       %fcos_body.fpn.prj_3.weight : Float(256, 256, 1, 1),
#       %fcos_body.fpn.prj_3.bias : Float(256),
#       %fcos_body.fpn.conv_5.weight : Float(256, 256, 3, 3),
#       %fcos_body.fpn.conv_5.bias : Float(256),
#       %fcos_body.fpn.conv_4.weight : Float(256, 256, 3, 3),
#       %fcos_body.fpn.conv_4.bias : Float(256),
#       %fcos_body.fpn.conv_3.weight : Float(256, 256, 3, 3),
#       %fcos_body.fpn.conv_3.bias : Float(256),
#       %fcos_body.fpn.conv_out6.weight : Float(256, 256, 3, 3),
#       %fcos_body.fpn.conv_out6.bias : Float(256),
#       %fcos_body.fpn.conv_out7.weight : Float(256, 256, 3, 3),
#       %fcos_body.fpn.conv_out7.bias : Float(256),
#       %fcos_body.head.cls_conv.0.weight : Float(256, 256, 3, 3),
#       %fcos_body.head.cls_conv.0.bias : Float(256),
#       %fcos_body.head.cls_conv.2.weight : Float(256, 256, 3, 3),
#       %fcos_body.head.cls_conv.2.bias : Float(256),
#       %fcos_body.head.cls_conv.4.weight : Float(256, 256, 3, 3),
#       %fcos_body.head.cls_conv.4.bias : Float(256),
#       %fcos_body.head.cls_conv.6.weight : Float(256, 256, 3, 3),
#       %fcos_body.head.cls_conv.6.bias : Float(256),
#       %fcos_body.head.reg_conv.0.weight : Float(256, 256, 3, 3),
#       %fcos_body.head.reg_conv.0.bias : Float(256),
#       %fcos_body.head.reg_conv.2.weight : Float(256, 256, 3, 3),
#       %fcos_body.head.reg_conv.2.bias : Float(256),
#       %fcos_body.head.reg_conv.4.weight : Float(256, 256, 3, 3),
#       %fcos_body.head.reg_conv.4.bias : Float(256),
#       %fcos_body.head.reg_conv.6.weight : Float(256, 256, 3, 3),
#       %fcos_body.head.reg_conv.6.bias : Float(256),
#       %fcos_body.head.cls_logits.weight : Float(20, 256, 3, 3),
#       %fcos_body.head.cls_logits.bias : Float(20),
#       %fcos_body.head.cnt_logits.weight : Float(1, 256, 3, 3),
#       %fcos_body.head.cnt_logits.bias : Float(1),
#       %fcos_body.head.reg_pred.weight : Float(4, 256, 3, 3),
#       %fcos_body.head.reg_pred.bias : Float(4)):
#   %147 : Float(1, 32, 320, 320) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%img, %fcos_body.backbone.block1.0.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/Conv2d[0]
#   %148 : Float(1, 32, 320, 320) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%147, %fcos_body.backbone.block1.1.weight, %fcos_body.backbone.block1.1.bias, %fcos_body.backbone.block1.1.running_mean, %fcos_body.backbone.block1.1.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/BatchNorm2d[1]
#   %149 : Float(1, 32, 320, 320) = onnx::LeakyRelu[alpha=0.1](%148), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/LeakyReLU[2]
#   %150 : Float(1, 32, 160, 160) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%149), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/MaxPool2d[3]
#   %151 : Float(1, 64, 160, 160) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%150, %fcos_body.backbone.block1.4.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/Conv2d[4]
#   %152 : Float(1, 64, 160, 160) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%151, %fcos_body.backbone.block1.5.weight, %fcos_body.backbone.block1.5.bias, %fcos_body.backbone.block1.5.running_mean, %fcos_body.backbone.block1.5.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/BatchNorm2d[5]
#   %153 : Float(1, 64, 160, 160) = onnx::LeakyRelu[alpha=0.1](%152), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/LeakyReLU[6]
#   %154 : Float(1, 64, 80, 80) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%153), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/MaxPool2d[7]
#   %155 : Float(1, 128, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%154, %fcos_body.backbone.block1.8.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/Conv2d[8]
#   %156 : Float(1, 128, 80, 80) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%155, %fcos_body.backbone.block1.9.weight, %fcos_body.backbone.block1.9.bias, %fcos_body.backbone.block1.9.running_mean, %fcos_body.backbone.block1.9.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/BatchNorm2d[9]
#   %157 : Float(1, 128, 80, 80) = onnx::LeakyRelu[alpha=0.1](%156), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/LeakyReLU[10]
#   %158 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%157, %fcos_body.backbone.block1.11.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/Conv2d[11]
#   %159 : Float(1, 64, 80, 80) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%158, %fcos_body.backbone.block1.12.weight, %fcos_body.backbone.block1.12.bias, %fcos_body.backbone.block1.12.running_mean, %fcos_body.backbone.block1.12.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/BatchNorm2d[12]
#   %160 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.1](%159), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/LeakyReLU[13]
#   %161 : Float(1, 128, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%160, %fcos_body.backbone.block1.14.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/Conv2d[14]
#   %162 : Float(1, 128, 80, 80) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%161, %fcos_body.backbone.block1.15.weight, %fcos_body.backbone.block1.15.bias, %fcos_body.backbone.block1.15.running_mean, %fcos_body.backbone.block1.15.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/BatchNorm2d[15]
#   %163 : Float(1, 128, 80, 80) = onnx::LeakyRelu[alpha=0.1](%162), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/LeakyReLU[16]
#   %164 : Float(1, 128, 40, 40) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%163), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/MaxPool2d[17]
#   %165 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%164, %fcos_body.backbone.block1.18.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/Conv2d[18]
#   %166 : Float(1, 256, 40, 40) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%165, %fcos_body.backbone.block1.19.weight, %fcos_body.backbone.block1.19.bias, %fcos_body.backbone.block1.19.running_mean, %fcos_body.backbone.block1.19.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/BatchNorm2d[19]
#   %167 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.1](%166), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/LeakyReLU[20]
#   %168 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%167, %fcos_body.backbone.block1.21.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/Conv2d[21]
#   %169 : Float(1, 128, 40, 40) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%168, %fcos_body.backbone.block1.22.weight, %fcos_body.backbone.block1.22.bias, %fcos_body.backbone.block1.22.running_mean, %fcos_body.backbone.block1.22.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/BatchNorm2d[22]
#   %170 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.1](%169), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/LeakyReLU[23]
#   %171 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%170, %fcos_body.backbone.block1.24.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/Conv2d[24]
#   %172 : Float(1, 256, 40, 40) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%171, %fcos_body.backbone.block1.25.weight, %fcos_body.backbone.block1.25.bias, %fcos_body.backbone.block1.25.running_mean, %fcos_body.backbone.block1.25.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/BatchNorm2d[25]
#   %173 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.1](%172), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block1]/LeakyReLU[26]
#   %174 : Float(1, 256, 20, 20) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%173), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/MaxPool2d[0]
#   %175 : Float(1, 512, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%174, %fcos_body.backbone.block2.1.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/Conv2d[1]
#   %176 : Float(1, 512, 20, 20) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%175, %fcos_body.backbone.block2.2.weight, %fcos_body.backbone.block2.2.bias, %fcos_body.backbone.block2.2.running_mean, %fcos_body.backbone.block2.2.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/BatchNorm2d[2]
#   %177 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.1](%176), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/LeakyReLU[3]
#   %178 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%177, %fcos_body.backbone.block2.4.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/Conv2d[4]
#   %179 : Float(1, 256, 20, 20) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%178, %fcos_body.backbone.block2.5.weight, %fcos_body.backbone.block2.5.bias, %fcos_body.backbone.block2.5.running_mean, %fcos_body.backbone.block2.5.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/BatchNorm2d[5]
#   %180 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.1](%179), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/LeakyReLU[6]
#   %181 : Float(1, 512, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%180, %fcos_body.backbone.block2.7.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/Conv2d[7]
#   %182 : Float(1, 512, 20, 20) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%181, %fcos_body.backbone.block2.8.weight, %fcos_body.backbone.block2.8.bias, %fcos_body.backbone.block2.8.running_mean, %fcos_body.backbone.block2.8.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/BatchNorm2d[8]
#   %183 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.1](%182), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/LeakyReLU[9]
#   %184 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%183, %fcos_body.backbone.block2.10.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/Conv2d[10]
#   %185 : Float(1, 256, 20, 20) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%184, %fcos_body.backbone.block2.11.weight, %fcos_body.backbone.block2.11.bias, %fcos_body.backbone.block2.11.running_mean, %fcos_body.backbone.block2.11.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/BatchNorm2d[11]
#   %186 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.1](%185), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/LeakyReLU[12]
#   %187 : Float(1, 512, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%186, %fcos_body.backbone.block2.13.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/Conv2d[13]
#   %188 : Float(1, 512, 20, 20) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%187, %fcos_body.backbone.block2.14.weight, %fcos_body.backbone.block2.14.bias, %fcos_body.backbone.block2.14.running_mean, %fcos_body.backbone.block2.14.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/BatchNorm2d[14]
#   %189 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.1](%188), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block2]/LeakyReLU[15]
#   %190 : Float(1, 512, 10, 10) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%189), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/MaxPool2d[0]
#   %191 : Float(1, 1024, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%190, %fcos_body.backbone.block3.1.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/Conv2d[1]
#   %192 : Float(1, 1024, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%191, %fcos_body.backbone.block3.2.weight, %fcos_body.backbone.block3.2.bias, %fcos_body.backbone.block3.2.running_mean, %fcos_body.backbone.block3.2.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/BatchNorm2d[2]
#   %193 : Float(1, 1024, 10, 10) = onnx::LeakyRelu[alpha=0.1](%192), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/LeakyReLU[3]
#   %194 : Float(1, 512, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%193, %fcos_body.backbone.block3.4.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/Conv2d[4]
#   %195 : Float(1, 512, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%194, %fcos_body.backbone.block3.5.weight, %fcos_body.backbone.block3.5.bias, %fcos_body.backbone.block3.5.running_mean, %fcos_body.backbone.block3.5.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/BatchNorm2d[5]
#   %196 : Float(1, 512, 10, 10) = onnx::LeakyRelu[alpha=0.1](%195), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/LeakyReLU[6]
#   %197 : Float(1, 1024, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%196, %fcos_body.backbone.block3.7.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/Conv2d[7]
#   %198 : Float(1, 1024, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%197, %fcos_body.backbone.block3.8.weight, %fcos_body.backbone.block3.8.bias, %fcos_body.backbone.block3.8.running_mean, %fcos_body.backbone.block3.8.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/BatchNorm2d[8]
#   %199 : Float(1, 1024, 10, 10) = onnx::LeakyRelu[alpha=0.1](%198), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/LeakyReLU[9]
#   %200 : Float(1, 512, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%199, %fcos_body.backbone.block3.10.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/Conv2d[10]
#   %201 : Float(1, 512, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%200, %fcos_body.backbone.block3.11.weight, %fcos_body.backbone.block3.11.bias, %fcos_body.backbone.block3.11.running_mean, %fcos_body.backbone.block3.11.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/BatchNorm2d[11]
#   %202 : Float(1, 512, 10, 10) = onnx::LeakyRelu[alpha=0.1](%201), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/LeakyReLU[12]
#   %203 : Float(1, 1024, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%202, %fcos_body.backbone.block3.13.weight), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/Conv2d[13]
#   %204 : Float(1, 1024, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%203, %fcos_body.backbone.block3.14.weight, %fcos_body.backbone.block3.14.bias, %fcos_body.backbone.block3.14.running_mean, %fcos_body.backbone.block3.14.running_var), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/BatchNorm2d[14]
#   %205 : Float(1, 1024, 10, 10) = onnx::LeakyRelu[alpha=0.1](%204), scope: FCOSDetectorDeploy/FCOS[fcos_body]/Darknet19[backbone]/Sequential[block3]/LeakyReLU[15]
#   %206 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%205, %fcos_body.fpn.prj_5.weight, %fcos_body.fpn.prj_5.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]/Conv2d[prj_5]
#   %207 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%189, %fcos_body.fpn.prj_4.weight, %fcos_body.fpn.prj_4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]/Conv2d[prj_4]
#   %208 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%173, %fcos_body.fpn.prj_3.weight, %fcos_body.fpn.prj_3.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]/Conv2d[prj_3]
#   %209 : Long() = onnx::Constant[value={2}](), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %210 : Tensor = onnx::Shape(%189), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %211 : Long() = onnx::Gather[axis=0](%210, %209), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %212 : Long() = onnx::Constant[value={3}](), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %213 : Tensor = onnx::Shape(%189), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %214 : Long() = onnx::Gather[axis=0](%213, %212), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %215 : Tensor = onnx::Unsqueeze[axes=[0]](%211)
#   %216 : Tensor = onnx::Unsqueeze[axes=[0]](%214)
#   %217 : Tensor = onnx::Concat[axis=0](%215, %216)
#   %218 : Tensor = onnx::Constant[value= 1  1 [ Variable[CPUType]{2} ]](), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %219 : Tensor = onnx::Cast[to=1](%217), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %220 : Tensor = onnx::Shape(%206), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %221 : Tensor = onnx::Slice[axes=[0], ends=[4], starts=[2]](%220), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %222 : Tensor = onnx::Cast[to=1](%221), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %223 : Tensor = onnx::Div(%219, %222), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %224 : Tensor = onnx::Concat[axis=0](%218, %223), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %225 : Float(1, 256, 20, 20) = onnx::Upsample[mode="nearest"](%206, %224), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %226 : Float(1, 256, 20, 20) = onnx::Add(%207, %225), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %227 : Long() = onnx::Constant[value={2}](), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %228 : Tensor = onnx::Shape(%173), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %229 : Long() = onnx::Gather[axis=0](%228, %227), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %230 : Long() = onnx::Constant[value={3}](), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %231 : Tensor = onnx::Shape(%173), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %232 : Long() = onnx::Gather[axis=0](%231, %230), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %233 : Tensor = onnx::Unsqueeze[axes=[0]](%229)
#   %234 : Tensor = onnx::Unsqueeze[axes=[0]](%232)
#   %235 : Tensor = onnx::Concat[axis=0](%233, %234)
#   %236 : Tensor = onnx::Constant[value= 1  1 [ Variable[CPUType]{2} ]](), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %237 : Tensor = onnx::Cast[to=1](%235), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %238 : Tensor = onnx::Shape(%226), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %239 : Tensor = onnx::Slice[axes=[0], ends=[4], starts=[2]](%238), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %240 : Tensor = onnx::Cast[to=1](%239), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %241 : Tensor = onnx::Div(%237, %240), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %242 : Tensor = onnx::Concat[axis=0](%236, %241), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %243 : Float(1, 256, 40, 40) = onnx::Upsample[mode="nearest"](%226, %242), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %244 : Float(1, 256, 40, 40) = onnx::Add(%208, %243), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %245 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%244, %fcos_body.fpn.conv_3.weight, %fcos_body.fpn.conv_3.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]/Conv2d[conv_3]
#   %246 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%226, %fcos_body.fpn.conv_4.weight, %fcos_body.fpn.conv_4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]/Conv2d[conv_4]
#   %247 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%206, %fcos_body.fpn.conv_5.weight, %fcos_body.fpn.conv_5.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]/Conv2d[conv_5]
#   %248 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%247, %fcos_body.fpn.conv_out6.weight, %fcos_body.fpn.conv_out6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]/Conv2d[conv_out6]
#   %249 : Float(1, 256, 5, 5) = onnx::Relu(%248), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]
#   %250 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%249, %fcos_body.fpn.conv_out7.weight, %fcos_body.fpn.conv_out7.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/FPN[fpn]/Conv2d[conv_out7]
#   %251 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%245, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[0]
#   %252 : Float(1, 256, 40, 40) = onnx::Relu(%251), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[1]
#   %253 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%252, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[2]
#   %254 : Float(1, 256, 40, 40) = onnx::Relu(%253), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[3]
#   %255 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%254, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[4]
#   %256 : Float(1, 256, 40, 40) = onnx::Relu(%255), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[5]
#   %257 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%256, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[6]
#   %258 : Float(1, 256, 40, 40) = onnx::Relu(%257), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[7]
#   %259 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%245, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[0]
#   %260 : Float(1, 256, 40, 40) = onnx::Relu(%259), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[1]
#   %261 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%260, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[2]
#   %262 : Float(1, 256, 40, 40) = onnx::Relu(%261), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[3]
#   %263 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%262, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[4]
#   %264 : Float(1, 256, 40, 40) = onnx::Relu(%263), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[5]
#   %265 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%264, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[6]
#   %266 : Float(1, 256, 40, 40) = onnx::Relu(%265), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[7]
#   %267 : Float(1, 20, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%258, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cls_logits]
#   %268 : Float(1, 1, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%266, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cnt_logits]
#   %269 : Float(1, 4, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%266, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[reg_pred]
#   %270 : Float(1, 4, 40, 40) = onnx::Exp(%269), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]
#   %271 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%246, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[0]
#   %272 : Float(1, 256, 20, 20) = onnx::Relu(%271), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[1]
#   %273 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%272, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[2]
#   %274 : Float(1, 256, 20, 20) = onnx::Relu(%273), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[3]
#   %275 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%274, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[4]
#   %276 : Float(1, 256, 20, 20) = onnx::Relu(%275), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[5]
#   %277 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%276, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[6]
#   %278 : Float(1, 256, 20, 20) = onnx::Relu(%277), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[7]
#   %279 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%246, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[0]
#   %280 : Float(1, 256, 20, 20) = onnx::Relu(%279), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[1]
#   %281 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%280, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[2]
#   %282 : Float(1, 256, 20, 20) = onnx::Relu(%281), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[3]
#   %283 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%282, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[4]
#   %284 : Float(1, 256, 20, 20) = onnx::Relu(%283), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[5]
#   %285 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%284, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[6]
#   %286 : Float(1, 256, 20, 20) = onnx::Relu(%285), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[7]
#   %287 : Float(1, 20, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%278, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cls_logits]
#   %288 : Float(1, 1, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%286, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cnt_logits]
#   %289 : Float(1, 4, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%286, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[reg_pred]
#   %290 : Float(1, 4, 20, 20) = onnx::Exp(%289), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]
#   %291 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%247, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[0]
#   %292 : Float(1, 256, 10, 10) = onnx::Relu(%291), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[1]
#   %293 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%292, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[2]
#   %294 : Float(1, 256, 10, 10) = onnx::Relu(%293), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[3]
#   %295 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%294, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[4]
#   %296 : Float(1, 256, 10, 10) = onnx::Relu(%295), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[5]
#   %297 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%296, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[6]
#   %298 : Float(1, 256, 10, 10) = onnx::Relu(%297), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[7]
#   %299 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%247, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[0]
#   %300 : Float(1, 256, 10, 10) = onnx::Relu(%299), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[1]
#   %301 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%300, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[2]
#   %302 : Float(1, 256, 10, 10) = onnx::Relu(%301), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[3]
#   %303 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%302, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[4]
#   %304 : Float(1, 256, 10, 10) = onnx::Relu(%303), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[5]
#   %305 : Float(1, 256, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%304, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[6]
#   %306 : Float(1, 256, 10, 10) = onnx::Relu(%305), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[7]
#   %307 : Float(1, 20, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%298, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cls_logits]
#   %308 : Float(1, 1, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%306, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cnt_logits]
#   %309 : Float(1, 4, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%306, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[reg_pred]
#   %310 : Float(1, 4, 10, 10) = onnx::Exp(%309), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]
#   %311 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%248, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[0]
#   %312 : Float(1, 256, 5, 5) = onnx::Relu(%311), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[1]
#   %313 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%312, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[2]
#   %314 : Float(1, 256, 5, 5) = onnx::Relu(%313), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[3]
#   %315 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%314, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[4]
#   %316 : Float(1, 256, 5, 5) = onnx::Relu(%315), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[5]
#   %317 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%316, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[6]
#   %318 : Float(1, 256, 5, 5) = onnx::Relu(%317), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[7]
#   %319 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%248, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[0]
#   %320 : Float(1, 256, 5, 5) = onnx::Relu(%319), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[1]
#   %321 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%320, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[2]
#   %322 : Float(1, 256, 5, 5) = onnx::Relu(%321), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[3]
#   %323 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%322, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[4]
#   %324 : Float(1, 256, 5, 5) = onnx::Relu(%323), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[5]
#   %325 : Float(1, 256, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%324, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[6]
#   %326 : Float(1, 256, 5, 5) = onnx::Relu(%325), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[7]
#   %327 : Float(1, 20, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%318, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cls_logits]
#   %328 : Float(1, 1, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%326, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cnt_logits]
#   %329 : Float(1, 4, 5, 5) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%326, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[reg_pred]
#   %330 : Float(1, 4, 5, 5) = onnx::Exp(%329), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]
#   %331 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%250, %fcos_body.head.cls_conv.0.weight, %fcos_body.head.cls_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[0]
#   %332 : Float(1, 256, 3, 3) = onnx::Relu(%331), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[1]
#   %333 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%332, %fcos_body.head.cls_conv.2.weight, %fcos_body.head.cls_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[2]
#   %334 : Float(1, 256, 3, 3) = onnx::Relu(%333), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[3]
#   %335 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%334, %fcos_body.head.cls_conv.4.weight, %fcos_body.head.cls_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[4]
#   %336 : Float(1, 256, 3, 3) = onnx::Relu(%335), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[5]
#   %337 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%336, %fcos_body.head.cls_conv.6.weight, %fcos_body.head.cls_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/Conv2d[6]
#   %338 : Float(1, 256, 3, 3) = onnx::Relu(%337), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[cls_conv]/ReLU[7]
#   %339 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%250, %fcos_body.head.reg_conv.0.weight, %fcos_body.head.reg_conv.0.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[0]
#   %340 : Float(1, 256, 3, 3) = onnx::Relu(%339), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[1]
#   %341 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%340, %fcos_body.head.reg_conv.2.weight, %fcos_body.head.reg_conv.2.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[2]
#   %342 : Float(1, 256, 3, 3) = onnx::Relu(%341), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[3]
#   %343 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%342, %fcos_body.head.reg_conv.4.weight, %fcos_body.head.reg_conv.4.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[4]
#   %344 : Float(1, 256, 3, 3) = onnx::Relu(%343), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[5]
#   %345 : Float(1, 256, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%344, %fcos_body.head.reg_conv.6.weight, %fcos_body.head.reg_conv.6.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/Conv2d[6]
#   %346 : Float(1, 256, 3, 3) = onnx::Relu(%345), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Sequential[reg_conv]/ReLU[7]
#   %347 : Float(1, 20, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%338, %fcos_body.head.cls_logits.weight, %fcos_body.head.cls_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cls_logits]
#   %348 : Float(1, 1, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%346, %fcos_body.head.cnt_logits.weight, %fcos_body.head.cnt_logits.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[cnt_logits]
#   %349 : Float(1, 4, 3, 3) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%346, %fcos_body.head.reg_pred.weight, %fcos_body.head.reg_pred.bias), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]/Conv2d[reg_pred]
#   %350 : Float(1, 4, 3, 3) = onnx::Exp(%349), scope: FCOSDetectorDeploy/FCOS[fcos_body]/ClsCntRegHead[head]
#   %351 : Tensor = onnx::Constant[value=  1  20  -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %352 : Float(1, 20, 1600) = onnx::Reshape(%267, %351), scope: FCOSDetectorDeploy
#   %353 : Tensor = onnx::Constant[value=  1  20  -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %354 : Float(1, 20, 400) = onnx::Reshape(%287, %353), scope: FCOSDetectorDeploy
#   %355 : Tensor = onnx::Constant[value=  1  20  -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %356 : Float(1, 20, 100) = onnx::Reshape(%307, %355), scope: FCOSDetectorDeploy
#   %357 : Tensor = onnx::Constant[value=  1  20  -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %358 : Float(1, 20, 25) = onnx::Reshape(%327, %357), scope: FCOSDetectorDeploy
#   %359 : Tensor = onnx::Constant[value=  1  20  -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %360 : Float(1, 20, 9) = onnx::Reshape(%347, %359), scope: FCOSDetectorDeploy
#   %361 : Float(1, 20, 2134) = onnx::Concat[axis=-1](%352, %354, %356, %358, %360), scope: FCOSDetectorDeploy
#   %cls : Float(1, 20, 2134) = onnx::Sigmoid(%361), scope: FCOSDetectorDeploy
#   %363 : Tensor = onnx::Constant[value= 1  1 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %364 : Float(1, 1, 1600) = onnx::Reshape(%268, %363), scope: FCOSDetectorDeploy
#   %365 : Tensor = onnx::Constant[value= 1  1 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %366 : Float(1, 1, 400) = onnx::Reshape(%288, %365), scope: FCOSDetectorDeploy
#   %367 : Tensor = onnx::Constant[value= 1  1 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %368 : Float(1, 1, 100) = onnx::Reshape(%308, %367), scope: FCOSDetectorDeploy
#   %369 : Tensor = onnx::Constant[value= 1  1 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %370 : Float(1, 1, 25) = onnx::Reshape(%328, %369), scope: FCOSDetectorDeploy
#   %371 : Tensor = onnx::Constant[value= 1  1 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %372 : Float(1, 1, 9) = onnx::Reshape(%348, %371), scope: FCOSDetectorDeploy
#   %373 : Float(1, 1, 2134) = onnx::Concat[axis=-1](%364, %366, %368, %370, %372), scope: FCOSDetectorDeploy
#   %cnt : Float(1, 1, 2134) = onnx::Sigmoid(%373), scope: FCOSDetectorDeploy
#   %375 : Tensor = onnx::Constant[value= 1  4 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %376 : Float(1, 4, 1600) = onnx::Reshape(%270, %375), scope: FCOSDetectorDeploy
#   %377 : Tensor = onnx::Constant[value= 1  4 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %378 : Float(1, 4, 400) = onnx::Reshape(%290, %377), scope: FCOSDetectorDeploy
#   %379 : Tensor = onnx::Constant[value= 1  4 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %380 : Float(1, 4, 100) = onnx::Reshape(%310, %379), scope: FCOSDetectorDeploy
#   %381 : Tensor = onnx::Constant[value= 1  4 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %382 : Float(1, 4, 25) = onnx::Reshape(%330, %381), scope: FCOSDetectorDeploy
#   %383 : Tensor = onnx::Constant[value= 1  4 -1 [ Variable[CPUType]{3} ]](), scope: FCOSDetectorDeploy
#   %384 : Float(1, 4, 9) = onnx::Reshape(%350, %383), scope: FCOSDetectorDeploy
#   %reg : Float(1, 4, 2134) = onnx::Concat[axis=-1](%376, %378, %380, %382, %384), scope: FCOSDetectorDeploy
#   return (%cls, %cnt, %reg)

# %% [markdown]
# ## 验证模型转换精度1--用原始的Pytorch推理图片

# %%
# 读取图片
img_name = 'test_images/000004.jpg'
img = cv2.imread(img_name)

# 需要将模型转换到float32
img = cv2.resize(img, (320,320)).astype('float32')

# 将模型从[320,320,3]变成[1,3,320,320]的推理形状
img = np.transpose(img, (2,0,1))[None,...]
img = torch.tensor(img)

# 以deploy模式建立FCOS检测器
model = FCOSDetectorDeploy(mode="deploy", config=DefaultConfig)
model = torch.nn.DataParallel(model)

# 加载预训练模型
model.load_state_dict(torch.load("./training_dir_fp16_nogn/model_24.pth",map_location=torch.device('cpu')))
model = model.eval()

# 拿到分类，中心度和回归的输出，并打印回归的输出方便与onnx的结果做对比
with torch.no_grad():
    cls1, cnt1, reg1 = model(img)
    print(reg1)
# Out:
# INFO: using darnet19 backbone
# tensor([[[3.5129e+02, 1.0395e+04, 8.7255e+03,  ..., 1.8458e+02,
#           7.5282e+02, 9.8308e+02],
#          [1.3531e+02, 3.2338e+02, 8.0767e+02,  ..., 6.3049e+05,
#           2.0588e+05, 5.4898e+02],
#          [1.4481e+03, 3.8759e+04, 7.5060e+05,  ..., 3.0634e+03,
#           1.7337e+02, 4.6023e+00],
#          [2.1421e+01, 3.4048e+00, 1.0136e+00,  ..., 1.4374e+02,
#           1.3487e+01, 4.3831e+00]]])
# /Users/calebge/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1386: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %% [markdown]
# ## 验证模型转换精度2--用ONNX推理图片

# %%
# 导入所需的onnxruntime包
# 如果没有这个包，则安装: pip install onnxruntime
import onnxruntime

# %%
# 读取图片
img_name = 'test_images/000004.jpg'
img = cv2.imread(img_name)

# 需要将模型转换到float32，否则无法推理
img = cv2.resize(img, (320,320)).astype('float32')

# 将模型从[320,320,3]变成[1,3,320,320]的推理格式
img = np.transpose(img, (2,0,1))[None,...]

# 使用onnxruntime加载转换好的fcos检测器
sess = onnxruntime.InferenceSession(name_converted, None)

# 使用onnxruntime进行推理，并打印回归输出
(cls2, cnt2, reg2) = sess.run(None, {'img': img})
print(reg2)
# Out:
# [[[3.51289093e+02 1.03950938e+04 8.72563379e+03 ... 1.84585175e+02
#    7.52820618e+02 9.83078430e+02]
#   [1.35305420e+02 3.23380798e+02 8.07670959e+02 ... 6.30485938e+05
#    2.05873422e+05 5.48978455e+02]
#   [1.44809155e+03 3.87590586e+04 7.50608750e+05 ... 3.06335059e+03
#    1.73369644e+02 4.60233307e+00]
#   [2.14211693e+01 3.40483952e+00 1.01360846e+00 ... 1.43739243e+02
#    1.34865055e+01 4.38306761e+00]]]

# %%
# 观察Pytorch到onnx在回归输出上的转换误差
reg1.numpy() - reg2
# Out:
# array([[[ 4.8828125e-04, -4.8828125e-02, -9.9609375e-02, ...,
#          -2.5939941e-04,  3.2348633e-03, -2.3803711e-03],
#         [ 7.7819824e-04, -6.4086914e-04, -4.6386719e-03, ...,
#           3.0000000e+00,  2.1718750e+00, -4.8828125e-04],
#         [ 5.4931641e-03, -1.8750000e-01, -7.8750000e+00, ...,
#           8.7890625e-03,  5.7983398e-04,  2.3841858e-06],
#         [ 9.1552734e-05,  9.5367432e-06,  4.0531158e-06, ...,
#           6.2561035e-04, -3.8146973e-06, -2.3841858e-06]]], dtype=float32)
